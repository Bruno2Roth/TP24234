-- %% [markdown]
-- # [TP6prog]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [TP6prog]    Script Date: 9/7/2025 00:07:37 ******/
CREATE DATABASE [TP6prog]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'TP6prog', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\TP6prog.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'TP6prog_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\TP6prog_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [TP6prog] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [TP6prog].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [TP6prog] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [TP6prog] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [TP6prog] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [TP6prog] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [TP6prog] SET ARITHABORT OFF 
GO
ALTER DATABASE [TP6prog] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [TP6prog] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [TP6prog] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [TP6prog] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [TP6prog] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [TP6prog] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [TP6prog] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [TP6prog] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [TP6prog] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [TP6prog] SET  DISABLE_BROKER 
GO
ALTER DATABASE [TP6prog] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [TP6prog] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [TP6prog] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [TP6prog] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [TP6prog] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [TP6prog] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [TP6prog] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [TP6prog] SET RECOVERY FULL 
GO
ALTER DATABASE [TP6prog] SET  MULTI_USER 
GO
ALTER DATABASE [TP6prog] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [TP6prog] SET DB_CHAINING OFF 
GO
ALTER DATABASE [TP6prog] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [TP6prog] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [TP6prog] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [TP6prog] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'TP6prog', N'ON'
GO
ALTER DATABASE [TP6prog] SET QUERY_STORE = ON
GO
ALTER DATABASE [TP6prog] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Grupos]

-- %%
USE [TP6prog]
GO

-- %%
/****** Object:  Table [dbo].[Grupos]    Script Date: 9/7/2025 00:07:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Grupos](
	[idGrupo] [int] IDENTITY(1,1) NOT NULL,
	[NombreGrupo] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[idGrupo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Integrantes]

-- %%
/****** Object:  Table [dbo].[Integrantes]    Script Date: 9/7/2025 00:07:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Integrantes](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[idGrupo] [int] NULL,
	[Nombre] [varchar](100) NULL,
	[Usuario] [varchar](50) NULL,
	[Contraseña] [varchar](50) NULL,
	[Frase] [varchar](300) NULL,
	[Hobby] [varchar](100) NULL,
	[ProfFavorito] [varchar](50) NULL,
	[PeliculaFav] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Grupos]

-- %%
SET IDENTITY_INSERT [dbo].[Grupos] ON 
INSERT [dbo].[Grupos] ([idGrupo], [NombreGrupo]) VALUES (1, N'Grupo Fran')
INSERT [dbo].[Grupos] ([idGrupo], [NombreGrupo]) VALUES (2, N'BrunoBerman')
INSERT [dbo].[Grupos] ([idGrupo], [NombreGrupo]) VALUES (3, N'Las Sinfonías')
SET IDENTITY_INSERT [dbo].[Grupos] OFF
GO

-- %% [markdown]
-- # [dbo].[Integrantes]

-- %%
SET IDENTITY_INSERT [dbo].[Integrantes] ON 
INSERT [dbo].[Integrantes] ([id], [idGrupo], [Nombre], [Usuario], [Contraseña], [Frase], [Hobby], [ProfFavorito], [PeliculaFav]) VALUES (1, 1, N'Fran Castillo', N'Frannnnn', N'Fran1234', N'AAAAAAAAAAAAAAA', N'Siesta', N'Iara', N'Secreto en la Montaña')
INSERT [dbo].[Integrantes] ([id], [idGrupo], [Nombre], [Usuario], [Contraseña], [Frase], [Hobby], [ProfFavorito], [PeliculaFav]) VALUES (2, 1, N'Zar Nicolas II', N'ZNicolas2', N'Russia1917', N'No sé nada del arte de gobernar', N'Gobernar', N'Iara', N'Anastasia')
INSERT [dbo].[Integrantes] ([id], [idGrupo], [Nombre], [Usuario], [Contraseña], [Frase], [Hobby], [ProfFavorito], [PeliculaFav]) VALUES (3, 1, N'Bob', N'Minions015', N'Banana', N'Bello!, Poopaye, Tank yu!', N'Comer', N'Iara', N'Mi Villano Favorito')
INSERT [dbo].[Integrantes] ([id], [idGrupo], [Nombre], [Usuario], [Contraseña], [Frase], [Hobby], [ProfFavorito], [PeliculaFav]) VALUES (4, 1, N'El Conejo de Nesquik', N'QuikyOK', N'Conej0', N'Siempre listo para el sabor', N'Tirar Facha', N'Iara', N'Space Jam')
INSERT [dbo].[Integrantes] ([id], [idGrupo], [Nombre], [Usuario], [Contraseña], [Frase], [Hobby], [ProfFavorito], [PeliculaFav]) VALUES (5, 1, N'Negro Tumbo', N'OscuroIntercesor', N'Fortin1920', N'Estoy para unas lineas de sal', N'Rituales', N'Iara', N'El Extraño Mundo de Jack')
INSERT [dbo].[Integrantes] ([id], [idGrupo], [Nombre], [Usuario], [Contraseña], [Frase], [Hobby], [ProfFavorito], [PeliculaFav]) VALUES (6, 2, N'Bruno Roth', N'Brunubi', N'EliTeAmo', N'Todo al rojo', N'Programar', N'Ceriana', N'La gran apuesta')
INSERT [dbo].[Integrantes] ([id], [idGrupo], [Nombre], [Usuario], [Contraseña], [Frase], [Hobby], [ProfFavorito], [PeliculaFav]) VALUES (7, 2, N'Messi', N'Li054', N'Messirve', N'Anda pa'' lla'' bobo', N'Flubo', N'Iara', N'Metegol')
INSERT [dbo].[Integrantes] ([id], [idGrupo], [Nombre], [Usuario], [Contraseña], [Frase], [Hobby], [ProfFavorito], [PeliculaFav]) VALUES (8, 2, N'Ronaldo', N'Cristian', N'CR7GOAT', N'Siuuuuuu', N'Flubo', N'Iara', N'El Futbol o Yo')
INSERT [dbo].[Integrantes] ([id], [idGrupo], [Nombre], [Usuario], [Contraseña], [Frase], [Hobby], [ProfFavorito], [PeliculaFav]) VALUES (9, 2, N'Mbappe', N'Mpape', N'Kylliaaan', N'Aguante las tortugas', N'Flubo', N'Iara', N'Las Tortugas Ninja')
INSERT [dbo].[Integrantes] ([id], [idGrupo], [Nombre], [Usuario], [Contraseña], [Frase], [Hobby], [ProfFavorito], [PeliculaFav]) VALUES (10, 2, N'Paredes', N'Pared', N'Leo20', N'Vamos a pintar paredes', N'Flubo', N'Iara', N'Rápidos y Furiosos 5')
INSERT [dbo].[Integrantes] ([id], [idGrupo], [Nombre], [Usuario], [Contraseña], [Frase], [Hobby], [ProfFavorito], [PeliculaFav]) VALUES (11, 3, N'Tobias Turquie', N'Tobito', N'MTobi09', N'No es una buena práctica', N'Hacer tableros trifasicos de alta tension', N'Damian', N'El violinista en el tejado')
INSERT [dbo].[Integrantes] ([id], [idGrupo], [Nombre], [Usuario], [Contraseña], [Frase], [Hobby], [ProfFavorito], [PeliculaFav]) VALUES (12, 3, N'Gero Benavidez', N'MomoLaDinastia', N'GeroVena', N'Pequeños placeres que tienen mis domingos, al levantarme a escuchar un poquitito de música clásica, ahora con Paladio; de la orquesta sinfónica japonesa. Y bueno nada, unos mates ahí desayunando. Un poquitito del campo.', N'Pilotear Areolineas Splinter', N'Iara', N'Salvando al soldado Ryan')
INSERT [dbo].[Integrantes] ([id], [idGrupo], [Nombre], [Usuario], [Contraseña], [Frase], [Hobby], [ProfFavorito], [PeliculaFav]) VALUES (13, 3, N'Alonso', N'Alonsito', N'Mantequita88', N'Manteca Mantecosa', N'Fotografía', N'Iara', N'La historia de Jan')
INSERT [dbo].[Integrantes] ([id], [idGrupo], [Nombre], [Usuario], [Contraseña], [Frase], [Hobby], [ProfFavorito], [PeliculaFav]) VALUES (14, 3, N'Teodoro Igal Perles', N'Teo_Perles', N'FerroPasionIarok', N'Oh no no no no no', N'Hacer Tik Toks', N'Iara', N'La historia de Jan')
INSERT [dbo].[Integrantes] ([id], [idGrupo], [Nombre], [Usuario], [Contraseña], [Frase], [Hobby], [ProfFavorito], [PeliculaFav]) VALUES (15, 3, N'Shlomo Levi', N'SholomoLev', N'Goyshe', N'Como ser un buen goy', N'Poner Tefilin', N'Iara', N'La purga')
SET IDENTITY_INSERT [dbo].[Integrantes] OFF
GO

-- %% [markdown]
-- # [FK__Integrant__idGru__3B75D760]

-- %%
ALTER TABLE [dbo].[Integrantes]  WITH CHECK ADD FOREIGN KEY([idGrupo])
REFERENCES [dbo].[Grupos] ([idGrupo])
GO

-- %% [markdown]
-- # [TP6prog]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [TP6prog] SET  READ_WRITE 
GO
